# %%
#necessary libraries 

import json
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

from sklearn.linear_model import LogisticRegression

import statsmodels.api as sm
from scipy import stats
from scipy.stats import ttest_1samp, ttest_rel, ttest_ind

# %% [markdown]
# After getting all the necessary data with Spotify API, framing and labelling ('Spotify API.ipynb' notebook), we can import csv file

# %%
#import dataset created in other jupyter notebook
data = pd.read_csv('my_data.csv')

# %%
#check the file: id, title, atist, features, labels (dependent variable)
data
# Out:
#                           id                             title  \
# 0     0TLAptKgYxe7F0KewWH6X6              I Need A Forest Fire
# 1     2y0rHDTckWQ7of6tI1yc82                        Naked Life
# 2     5nVE45ithgyVocZp5XLAk6                 The Bug Collector
# 3     66VuLX5s1nrZzzQqJqPbri                        Simply Are
# 4     0X61Ud5Uzv44RvY3s1SsuO                            Imogen
# ...                      ...                               ...
# 2640  3485UyMhs2ZF50l9sIZEys                            FINAIS
# 2641  7szuecWAPwGoV1e5vGu8tl                      In Your Eyes
# 2642  4Ty4XfOHdUFIXmVtBIFMIG                             XPIDI
# 2643  1xQ6trAsedVPCdbtDAmk0c  Savage Love (Laxed - Siren Beat)
# 2644  1fobXPCu47gikLMIoyQBLy                         Tranquilo
#
#             main_artist  danceability  energy  key  loudness  mode  \
# 0              Bon Iver         0.293   0.290    2   -11.596     1
# 1            Oko Ebombo         0.624   0.321    0    -9.776     1
# 2     Haley Heynderickx         0.538   0.419   10    -9.705     1
# 3          Arto Lindsay         0.682   0.694    7   -11.393     0
# 4           Nick Mulvey         0.493   0.584    5    -6.894     1
# ...                 ...           ...     ...  ...       ...   ...
# 2640        benji price         0.750   0.615   11    -7.532     0
# 2641         The Weeknd         0.667   0.719    7    -5.371     0
# 2642        benji price         0.840   0.475    5    -6.665     0
# 2643       Jason Derulo         0.767   0.481    0    -8.520     0
# 2644             Aragão         0.770   0.546   10    -8.113     0
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.69600          0.875000    0.1000   0.0373  128.276       257220
# 1          0.46300          0.056000    0.1030   0.3040   73.996       255030
# 2          0.77700          0.329000    0.0967   0.5290   99.622       228460
# 3          0.28900          0.714000    0.0961   0.9540  173.851       224107
# 4          0.85000          0.000353    0.1140   0.2340   86.909       255533
# ...            ...               ...       ...      ...      ...          ...
# 2640       0.64200          0.000000    0.2380   0.8330   75.986       207749
# 2641       0.00285          0.000081    0.0736   0.7170  100.021       237520
# 2642       0.64100          0.000000    0.0983   0.8820   77.006       172064
# 2643       0.23400          0.000000    0.2690   0.7610  150.076       171375
# 2644       0.62900          0.006100    0.0938   0.3820   98.032       263131
#
#       time_signature  Like
# 0                  4     1
# 1                  4     1
# 2                  4     1
# 3                  4     1
# 4                  4     1
# ...              ...   ...
# 2640               4     0
# 2641               4     0
# 2642               4     0
# 2643               4     0
# 2644               4     0
#
# [2645 rows x 16 columns]

# %%
data =  data.dropna()

# %%
data['Like'].unique()
# Out:
# array([1, 0])

# %%
data.columns
# Out:
# Index(['id', 'title', 'main_artist', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'Like'],
#       dtype='object')

# %% [markdown]
# ##### Split the dataset: Test and Training data

# %%
X = data[['danceability', 'energy', 'key','loudness', 'mode', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature']]
y = data['Like']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.3)

# %% [markdown]
# ## First ML algorithms

# %% [markdown]
# ### Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l2', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr_pred = lr_model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, lr_pred))
# Out:
# Accuracy: 0.7670025188916877

# %% [markdown]
# ### Random Forest

# %%
#Training the Algorithm

from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8602015113350125

# %%
#Evaluating the Algorithm

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[371  38]
#  [ 73 312]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       409
#            1       0.89      0.81      0.85       385
#
#     accuracy                           0.86       794
#    macro avg       0.86      0.86      0.86       794
# weighted avg       0.86      0.86      0.86       794

# %% [markdown]
# ### Check results

# %%
predict_df = X_test
predict_df['prediction'] = y_pred
predict_df['Like'] = data['Like']
predict_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       danceability  energy  key  loudness  mode  acousticness  \
# 2578         0.672  0.7410   11    -6.449     0        0.0803
# 457          0.512  0.7060    6    -5.244     1        0.0275
# 670          0.638  0.6680    2    -3.442     1        0.0822
# 2597         0.776  0.6960    7    -6.533     0        0.3000
# 92           0.466  0.0528    0   -12.281     1        0.1860
# ...            ...     ...  ...       ...   ...           ...
# 964          0.411  0.4700    9    -6.821     1        0.2840
# 2012         0.790  0.6940    9    -7.726     0        0.1450
# 665          0.370  0.5150    2    -9.487     0        0.0233
# 795          0.262  0.7900    8    -6.942     0        0.4060
# 1140         0.709  0.7390    4    -8.734     0        0.7590
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 2578          0.000000    0.1320    0.380  103.018       191253
# 457           0.000049    0.1640    0.703  114.036       167133
# 670           0.000000    0.0815    0.299  113.945       208766
# 2597          0.000003    0.1090    0.578   95.985       198720
# 92            0.168000    0.1600    0.729  140.765       407440
# ...                ...       ...      ...      ...          ...
# 964           0.000002    0.0765    0.294  131.734       286172
# 2012          0.002520    0.2810    0.508  103.007       181436
# 665           0.205000    0.0966    0.420  115.732       467320
# 795           0.321000    0.1650    0.493  196.957       437540
# 1140          0.004860    0.1090    0.751  169.971       274373
#
#       time_signature  prediction  Like
# 2578               4           0     0
# 457                4           0     1
# 670                4           0     1
# 2597               4           0     0
# 92                 4           1     1
# ...              ...         ...   ...
# 964                4           1     1
# 2012               4           0     0
# 665                4           0     1
# 795                4           1     1
# 1140               4           1     1
#
# [794 rows x 14 columns]

# %%
predict_df = predict_df.merge(data[['title','main_artist']], left_index=True, right_index=True)

# %%
final_prediction = predict_df[['title','main_artist','Like','prediction']]
final_prediction['Check'] = np.where(final_prediction['prediction']==final_prediction['Like'], 'Correct', 'Wrong')
wrong_pred = final_prediction[final_prediction['Check'] == 'Wrong']

wrong_titles = list(wrong_pred['title'])
wrong_pred
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               title        main_artist  Like  \
# 457                                Nem Fé nem Santo    Mallu Magalhães     1
# 670                             Cigarette Daydreams  Cage The Elephant     1
# 2018                                 Eu Gosto de Ti               ELAS     0
# 1047              Conto de Fadas de Sintra a Lisboa   Os Pontos Negros     1
# 2290                              Love You to Death    Type O Negative     0
# ...                                             ...                ...   ...
# 2502                     Kriolu (feat. Julinho KSD)        Julinho Ksd     0
# 1015                                     Santamaria             Canova     1
# 1992                                       Unspoken        Aaron Smith     0
# 249                                      Love Again      Daniel Caesar     1
# 665   I Want You (She's So Heavy) - Remastered 2009        The Beatles     1
#
#       prediction  Check
# 457            0  Wrong
# 670            0  Wrong
# 2018           1  Wrong
# 1047           0  Wrong
# 2290           1  Wrong
# ...          ...    ...
# 2502           1  Wrong
# 1015           0  Wrong
# 1992           1  Wrong
# 249            0  Wrong
# 665            0  Wrong
#
# [111 rows x 5 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(data[data['Like']==1]['danceability'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['danceability'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(data[data['Like']==1]['energy'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['energy'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(data[data['Like']==1]['key'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['key'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(data[data['Like']==1]['loudness'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['loudness'], color='blue', bins=40)
plt.legend((1,0))

plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(data[data['Like']==1]['mode'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['mode'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(data[data['Like']==1]['acousticness'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['acousticness'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(data[data['Like']==1]['instrumentalness'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['instrumentalness'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(data[data['Like']==1]['liveness'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['liveness'], color='blue', bins=40)
plt.legend((1,0))


plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(data[data['Like']==1]['valence'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['valence'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(data[data['Like']==1]['tempo'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['tempo'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(data[data['Like']==1]['duration_ms'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['duration_ms'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(data[data['Like']==1]['time_signature'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['time_signature'], color='blue', bins=40)
plt.legend((1,0))

# %%
corr = data.corr()
corr
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000  0.062039  0.016643  0.279247 -0.122610
# energy                0.062039  1.000000  0.010035  0.737551 -0.051832
# key                   0.016643  0.010035  1.000000 -0.023780 -0.131031
# loudness              0.279247  0.737551 -0.023780  1.000000 -0.074167
# mode                 -0.122610 -0.051832 -0.131031 -0.074167  1.000000
# acousticness         -0.074156 -0.734008 -0.004551 -0.545292  0.061559
# instrumentalness     -0.139850 -0.177746  0.022040 -0.374980 -0.010765
# liveness             -0.080928  0.180211 -0.012629  0.087556  0.002164
# valence               0.523299  0.390527  0.011916  0.393779 -0.053309
# tempo                -0.069122  0.199763 -0.005217  0.138149 -0.002407
# duration_ms          -0.389300  0.023120 -0.035193 -0.104683  0.018916
# time_signature        0.148891  0.156666 -0.008799  0.147276 -0.051913
# Like                 -0.180245 -0.595209 -0.003121 -0.559831  0.056580
#
#                   acousticness  instrumentalness  liveness   valence  \
# danceability         -0.074156         -0.139850 -0.080928  0.523299
# energy               -0.734008         -0.177746  0.180211  0.390527
# key                  -0.004551          0.022040 -0.012629  0.011916
# loudness             -0.545292         -0.374980  0.087556  0.393779
# mode                  0.061559         -0.010765  0.002164 -0.053309
# acousticness          1.000000          0.154207 -0.107108 -0.262904
# instrumentalness      0.154207          1.000000 -0.058640 -0.159249
# liveness             -0.107108         -0.058640  1.000000  0.046407
# valence              -0.262904         -0.159249  0.046407  1.000000
# tempo                -0.172892         -0.030166  0.035224  0.111843
# duration_ms          -0.084527          0.042699 -0.003220 -0.295536
# time_signature       -0.116281         -0.048235 -0.034971  0.121524
# Like                  0.521724          0.319217 -0.076785 -0.267845
#
#                      tempo  duration_ms  time_signature      Like
# danceability     -0.069122    -0.389300        0.148891 -0.180245
# energy            0.199763     0.023120        0.156666 -0.595209
# key              -0.005217    -0.035193       -0.008799 -0.003121
# loudness          0.138149    -0.104683        0.147276 -0.559831
# mode             -0.002407     0.018916       -0.051913  0.056580
# acousticness     -0.172892    -0.084527       -0.116281  0.521724
# instrumentalness -0.030166     0.042699       -0.048235  0.319217
# liveness          0.035224    -0.003220       -0.034971 -0.076785
# valence           0.111843    -0.295536        0.121524 -0.267845
# tempo             1.000000     0.031704        0.024543 -0.157498
# duration_ms       0.031704     1.000000       -0.037803  0.033219
# time_signature    0.024543    -0.037803        1.000000 -0.128135
# Like             -0.157498     0.033219       -0.128135  1.000000

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

f, ax = plt.subplots(figsize=(12, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
from IPython.display import display, Image, SVG, Math, YouTubeVideo
Image(filename='../images/features.png')

# %%
Image(filename='../images/features2.png')

# %% [markdown]
# ## TEMPO. Simply put, how many beats per minute (BPM) does each song have?
#
# Tempos are also related to different Genres
#
# - Hip Hop	85–95 BPM
# - Glitch Hop	105–115 BPM
# - Techno	120–125 BPM
# - House	& POP 115–130 BPM
# - Electro	128 BPM
# - Reggaeton >130 BPM
# - Dubstep	140 BPM

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.distplot(data[data['Like']==1]['tempo'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['tempo'], color='blue', bins=40)
plt.legend((1,0))

#we see 3 picks for disliked songs:
#one between 90-110 -> prob pop
#125-140 --> sertanejo
#170-290 ---> Anitta, Reggaeton

# %%
data[data['Like']==0].sort_values("tempo", ascending = False).head(30)
# Out:
#                           id  \
# 1943  6MNGxu8MprKGkchUchkJsy
# 2373  4MbJlBkNTEXGJ0sL8U5ABN
# 2375  4lRvl2PMPqavdm4Q1qNV0M
# 2609  190U8w42yxwiVqY8Tof8Dd
# 1618  4sO6Ixf414qYGlGqMETzMF
# 1368  6fkfMwMVgFJik4ljNMHGrB
# 2422  2AjEKcRXkntPkujLXp6hGD
# 2157  5t6z9HeNkHWVp0YiXIlSBQ
# 2119  4GMQOjbWshf4Mzphkjg0DJ
# 1937  5UE8e9VTMmv5fjGXLETjCf
# 1511  7na7Bk98usp84FaOJFPv3d
# 1622  7AlfoiKXfXzwVPE9asKNCs
# 2129  1H32DaOTgHMtncpL3JzyF5
# 2111  0SEd8AUWG3j4YFsFEVmGjW
# 2099  4yCwQQHlvzZpjaHeIjD3uU
# 1588  2wi1PzAsCczyseWIlxCvCK
# 1664  7zwOSMqWghSCfZrVo5r5nR
# 2053  0XIIRCazywV0esGSP1pVj5
# 1590  2NxCWAnGWVawMHx7CErikq
# 1576  6sYaS0lARqu6OX6QHf3kzY
# 1686  0VsddQbaQeHyTKCeE4ZN4s
# 1397  41VwdVXuOP08T3IBTRwyd2
# 2039  0wVFtfUnFotGMSxPlG56a7
# 1935  5Bn6W4bwH7Bw5nMvn8V4xF
# 2631  31sUabnuTnFAM7rjMzKtfN
# 1615  4VgYtXCVJ7IbWAZ5ryfvEQ
# 1513  0vRPGvIiFaRwohogbqmzKx
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 1943          0.000000    0.1710   0.5380  212.117       181733
# 2373          0.014900    0.2310   0.5210  199.999       266015
# 2375          0.733000    0.3060   0.1490  199.887       270746
# 2609          0.000000    0.1150   0.3360  199.879       206053
# 1618          0.000006    0.1020   0.7700  196.005       198367
# 1368          0.000000    0.3780   0.6670  195.867       221122
# 2422          0.130000    0.1320   0.2690  195.058       279692
# 2157          0.193000    0.2540   0.0674  195.042       573267
# 2119          0.031700    0.0720   0.4080  194.639       322933
# 1937          0.000001    0.0795   0.4220  194.026       171547
# 1511          0.000000    0.0625   0.7450  193.896       202887
# 1622          0.000000    0.1420   0.5030  193.747       160825
# 2129          0.009800    0.1550   0.4420  193.364       459173
# 2111          0.000021    0.3430   0.2810  192.622       160867
# 2099          0.005520    0.3360   0.6850  192.321       230693
# 1588          0.003510    0.1130   0.8060  192.138       204398
# 1664          0.000011    0.0807   0.8020  191.985       220000
# 2053          0.000006    0.1070   0.3390  191.485       220305
# 1590          0.000000    0.1040   0.7620  190.118       176849
# 1576          0.000019    0.1560   0.7600  190.051       224842
# 1686          0.000010    0.1010   0.5740  190.000       224380
# 1397          0.000014    0.0586   0.5540  189.952       224842
# 2039          0.000000    0.1770   0.6290  189.902       228325
# 1935          0.000000    0.1180   0.9040  189.887       160893
# 2631          0.000000    0.2580   0.4000  188.359       246369
# 1615          0.000014    0.5650   0.9190  188.081       194892
# 1513          0.000008    0.0874   0.6110  187.997       238347
# 1362          0.000000    0.0795   0.5510  187.857       188680
# 2387          0.137000    0.1550   0.4430  187.748       345573
# 1683          0.000096    0.1520   0.7340  186.096       272800
#
#       time_signature  Like
# 1943               4     0
# 2373               4     0
# 2375               3     0
# 2609               3     0
# 1618               4     0
# 1368               4     0
# 2422               3     0
# 2157               4     0
# 2119               4     0
# 1937               4     0
# 1511               4     0
# 1622               4     0
# 2129               4     0
# 2111               4     0
# 2099               4     0
# 1588               4     0
# 1664               4     0
# 2053               4     0
# 1590               4     0
# 1576               4     0
# 1686               4     0
# 1397               4     0
# 2039               4     0
# 1935               4     0
# 2631               4     0
# 1615               4     0
# 1513               4     0
# 1362               4     0
# 2387               4     0
# 1683               4     0

# %%
data[data['Like']==1]['tempo'].mean() #Thanks Frank Ocean!!
# Out:
# 115.80208957528971

# %%
data[data['Like']==0]['tempo'].mean()
# Out:
# 125.51170148148132

# %% [markdown]
# ## ENERGY. This is the first of Spotify’s more subjective metrics.
#
# ###### According to the API documentation:
# Energy represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale.

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.distplot(data[data['Like']==1]['energy'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['energy'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize = (6, 4))
ax = sns.boxplot(x='Like', y='energy', data = data)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
print(data[data['Like']==1]['energy'].mean()) 
print(data[data['Like']==0]['energy'].mean())

x = data[data['Like']==1]['energy']
y = data[data['Like']==0]['energy']

print(stats.ttest_ind(x,y)) #totally reject the H0 

#there are significant differences between the two groups on the ENERGY feature
# Out:
# 0.45861010038609984
# 0.7312437037037048
# Ttest_indResult(statistic=-38.079775089009445, pvalue=2.47972930830046e-253)

# %% [markdown]
# #### What artists are driving this ENERGY score on my liked songs?

# %%
lower_energy = data[data['Like']==1].sort_values("energy").head(30)
lower_energy
# Out:
#                           id  \
# 143   769vrJXv69vVKlZjX9XJ4W
# 68    4QwzVlAJSkcLeCNQ6Ug30P
# 568   2rewrH6juNsrGRtkMbNKAe
# 556   2TfNMJMvnILjmL8fSYlGAy
# 875   59J9tAbY39foKp478aUsWX
# 565   0u0IIYFZXtmtKTJilgOI3Z
# 557   2uEgyXzyJBr5Iuvqc83d4N
# 127   2ChIDG3Ae88OSrocGzjZzT
# 132   73Uc6U9BTEFoGP5ywB6MLr
# 19    4IhTXiZLKATmwhMZIb1GQN
# 182   5zVME2t9iqUQWLiaADwyS2
# 1020  3ZV87D1YcdCJhynXdTiqVu
# 564   6ZbdcZO79W18dTwXf356Gp
# 92    5rukCrVfbHZrQBh9E6qmmt
# 830   1xF030urgdbtdHHOgwRGgy
# 1037  2myQE9T8UAbl5u6Wg3UT2J
# 382   4ibV0gdPQYoTqvBwckNRlP
# 1292  2KNMqqNd3sLfeN4ukKduRT
# 41    4m1KsLnr0vI8nntJnsrXTI
# 491   6j9pCKVaJYNF7AdaNVTAaE
# 406   7bcsnVCS4rCicgaLGlO371
# 628   6eICehJWzcEk2880W6Apif
# 586   5tyMJlMqaggzvuX7TtlrTe
# 717   3yiXy2ydZP9ZpsYxvUI6sO
# 634   2OLOQnVA7T76HdqhVKyNWC
# 954   2UukB3C0jfVVcHLYlSVior
# 139   2YItmEbRbOhAHevysQ1QLr
# 236   5PsGfCv1s5iEwEy27e2poj
# 403   1RuyGO0kmkNkfixUFKkjuC
# 426   7oRNU7Tmek0nm2lqyDojoG
#
#                                                   title    main_artist  \
# 143                                Meet You In The Maze    James Blake
# 68                               The touch of your lips     Chet Baker
# 568                             I work for the Universe    Nick Murphy
# 556                                           Blood And    Nick Murphy
# 875   Satisfied Mind - Live at WFMU, East Orange, NJ...   Jeff Buckley
# 565                                     Tongue (Lift 4)    Nick Murphy
# 557                 And You Don’t Even Know You Hurt Me    Nick Murphy
# 127                            Lullaby For My Insomniac    James Blake
# 132                                      f.o.r.e.v.e.r.    James Blake
# 19                                        Lights Are On  Tom Rosenthal
# 182                                              Sister     Ben Howard
# 1020                                                Ela  Tim Bernardes
# 564                                   Blue Spotted Tail    Fleet Foxes
# 92                                            Mané-Mané      B Fachada
# 830                                     Summer All Over    Blake Mills
# 1037                                         Intimidade     Caramelows
# 382                                            deep fry      Expedidor
# 1292                                         Moon River  Frank Sinatra
# 41                                         Quem Me Dera    Valter Lobo
# 491                                               White     John Mayer
# 406                                              Marion       Bon Iver
# 628                                              Marion       Bon Iver
# 406           0.000072    0.1080   0.2380   96.771       141667
# 628           0.000030    0.1080   0.2350   79.694       141667
# 586           0.000368    0.0807   0.2410  134.238       229326
# 717           0.000003    0.1230   0.1070   76.470       228009
# 634           0.398000    0.2620   0.1170  116.945       366200
# 954           0.000679    0.1280   0.0859   79.298       196812
# 139           0.032500    0.0967   0.1200  135.491       213621
# 236           0.917000    0.1110   0.0607   92.317       289000
# 403           0.316000    0.1210   0.3010  125.023       401413
# 426           0.420000    0.1140   0.0925  114.358       160093
#
#       time_signature  Like
# 143                4     1
# 68                 4     1
# 568                4     1
# 556                4     1
# 875                3     1
# 565                5     1
# 557                4     1
# 127                5     1
# 132                3     1
# 19                 4     1
# 182                3     1
# 1020               3     1
# 564                4     1
# 92                 4     1
# 830                3     1
# 1037               4     1
# 382                4     1
# 1292               3     1
# 41                 3     1
# 491                4     1
# 406                4     1
# 628                3     1
# 586                4     1
# 717                4     1
# 634                4     1
# 954                5     1
# 139                4     1
# 236                4     1
# 403                4     1
# 426                3     1

# %%
lower_energy['main_artist'].value_counts().head(10)

#Bon Iver
#Frank Ocean
#James Blake
#Nick Murphy fka Chet Faket
#Tim Bernardes, B Fachada
# Out:
# James Blake      4
# Nick Murphy      4
# Bon Iver         4
# Tim Bernardes    2
# Tom Rosenthal    1
# B Fachada        1
# John Mayer       1
# Letrux           1
# Valter Lobo      1
# Kikagaku Moyo    1
# Name: main_artist, dtype: int64

# %% [markdown]
# #### Thank's Nick fka Chet Faker

# %%
Image(filename='../images/Chet Faker.png')

# %% [markdown]
# ## DANCEABILITY.
#
# ###### According to the API documentation:
# Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity.

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.distplot(data[data['Like']==1]['danceability'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['danceability'], color='blue', bins=40)
plt.legend((1,0))

# %% [markdown]
# Looks like while my 'disliked' songs follow a skewed distribution torwards higher levels of danceability, my loved songs follow a super normal distribution on this feature showing that I enjoy a wide range of danceability level

# %% [markdown]
# #### Songs with lowest danceability

# %%
low_dance = data[data['Like']==1].sort_values(by="danceability").head(50)

# %%
low_dance['main_artist'].value_counts().head(10)
# Out:
# Lana Del Rey     7
# Nick Murphy      4
# Ben Howard       3
# Tash Sultana     3
# James Blake      3
# Frank Ocean      2
# Daniel Caesar    2
# B Fachada        2
# Air              1
# The Murlocs      1
# Name: main_artist, dtype: int64

# %% [markdown]
# ##### The fault's on this beautiful album..... guess LDR doesn't wanna dance w/ me

# %%
Image(filename='../images/LDR.png')

# %% [markdown]
# Spotify doesn’t give any further details as to the exact calculation behind ‘danceability’, but we can find a clue in comparing the two features
#
# ### ENERGY vs DANCEABILITY

# %%
sns.lmplot(x="energy", y="danceability", data=data, hue='Like').fig.set_size_inches(10,8)

#from the graph below we can see that I do enjoy songs with normal level of dancability but low energy
#the imagine shows two very distinct clusters

# %% [markdown]
# #### What is driving a High danceability but low Energy?

# %%
high_dance_lower_energy = data[data['Like']==1].sort_values(by="danceability", ascending=False).head(20)
high_dance_lower_energy

#Indie, lo-fi music
# Out:
#                           id                                           title  \
# 1198  6iHgkGwqtr5f4A6qMk0zdC                                 Tango In Harlem
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 1198        0.2640          0.382000    0.0885    0.765  131.080       205600
# 1102        0.7730          0.021500    0.0800    0.878  120.715       259707
# 42          0.4430          0.168000    0.0969    0.473  119.902       183133
# 1219        0.0862          0.490000    0.0889    0.612  119.896       285440
# 1167        0.5430          0.323000    0.0904    0.757  104.981        59481
# 1004        0.1240          0.171000    0.0905    0.761  123.027       383840
# 1184        0.4630          0.000000    0.1100    0.882  127.004       184274
# 1254        0.1720          0.558000    0.1100    0.394   95.009       358679
# 332         0.1990          0.866000    0.1030    0.918  129.884       110769
# 467         0.0272          0.000503    0.1670    0.497  123.061       234093
# 1255        0.6150          0.907000    0.0840    0.364  108.017       363095
# 331         0.3730          0.918000    0.0504    0.799   98.066       118491
# 7           0.1970          0.000000    0.0796    0.865  126.021       160238
# 1225        0.7850          0.813000    0.1750    0.488   81.016       149707
# 311         0.6310          0.614000    0.1090    0.705   80.011       122938
# 1043        0.4850          0.000010    0.0732    0.750   97.975       201655
# 982         0.9130          0.000000    0.1280    0.698  106.105       120166
# 991         0.1740          0.000000    0.1390    0.731  118.025       169587
# 211         0.7760          0.019300    0.1070    0.442   74.997       212460
# 921         0.7860          0.231000    0.1780    0.115  125.426       146842
#
#       time_signature  Like
# 1198               4     1
# 1102               4     1
# 42                 3     1
# 1219               4     1
# 1167               4     1
# 1004               4     1
# 1184               4     1
# 1254               4     1
# 332                4     1
# 467                4     1
# 1255               4     1
# 331                4     1
# 7                  4     1
# 1225               4     1
# 311                4     1
# 1043               4     1
# 982                4     1
# 991                4     1
# 211                4     1
# 921                4     1

# %% [markdown]
# ## KEY
#
# - The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation .
# - E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.

# %%
#count how many songs have non detected key

data[data['key'] ==-1]

#all songs have identified key! that's cool
# Out:
# Empty DataFrame
# Columns: [id, title, main_artist, danceability, energy, key, loudness, mode, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature, Like]
# Index: []

# %% [markdown]
# ##### Note one thing from the key description above: "0 = C, 1 = C♯/D♭, 2 = D"

# %%
data.loc[data['key'] == 0, 'key_object'] = 'C'
data.loc[data['key'] == 1, 'key_object'] = 'C♯'
data.loc[data['key'] == 2, 'key_object'] = 'D'
data.loc[data['key'] == 3, 'key_object'] = 'D♯'
data.loc[data['key'] == 4, 'key_object'] = 'E'#Remember that E and B don't have#
data.loc[data['key'] == 5, 'key_object'] = 'F'
data.loc[data['key'] == 6, 'key_object'] = 'F♯'
data.loc[data['key'] == 7, 'key_object'] = 'G'
data.loc[data['key'] == 8, 'key_object'] = 'G♯'
data.loc[data['key'] == 9, 'key_object'] = 'A'
data.loc[data['key'] == 10, 'key_object'] = 'A♯'
data.loc[data['key'] == 11, 'key_object'] = 'B'

# %%
data.head()
# Out:
#                        id                 title        main_artist  \
# 0  0TLAptKgYxe7F0KewWH6X6  I Need A Forest Fire           Bon Iver
# 1  2y0rHDTckWQ7of6tI1yc82            Naked Life         Oko Ebombo
# 2  5nVE45ithgyVocZp5XLAk6     The Bug Collector  Haley Heynderickx
# 3  66VuLX5s1nrZzzQqJqPbri            Simply Are       Arto Lindsay
# 4  0X61Ud5Uzv44RvY3s1SsuO                Imogen        Nick Mulvey
#
#    danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0         0.293   0.290    2   -11.596     1         0.696          0.875000
# 1         0.624   0.321    0    -9.776     1         0.463          0.056000
# 2         0.538   0.419   10    -9.705     1         0.777          0.329000
# 3         0.682   0.694    7   -11.393     0         0.289          0.714000
# 4         0.493   0.584    5    -6.894     1         0.850          0.000353
#
#    liveness  valence    tempo  duration_ms  time_signature  Like key_object
# 0    0.1000   0.0373  128.276       257220               4     1          D
# 1    0.1030   0.3040   73.996       255030               4     1          C
# 2    0.0967   0.5290   99.622       228460               4     1         A♯
# 3    0.0961   0.9540  173.851       224107               4     1          G
# 4    0.1140   0.2340   86.909       255533               4     1          F

# %%
data['key_object'].unique()
# Out:
# array(['D', 'C', 'A♯', 'G', 'F', 'C♯', 'D♯', 'G♯', 'F♯', 'B', 'A', 'E'],
#       dtype=object)

# %%
#export to use in tableau dashboard
data.to_csv (r'my_data2.csv', index = False, header=True)

# %%
#graph from tableau 

Image(filename='../images/graph_keys.png')

# %%
#graph from tableau 
Image(filename='../images/graph_keys2.png')

# %%
data[data['title'] == "'Cause I'm A Man"]
# Out:
#                          id             title  main_artist  danceability  \
# 673  2O99aywAVBhaPrsiJ6zbSS  'Cause I'm A Man  Tame Impala         0.547
#
#      energy  key  loudness  mode  acousticness  instrumentalness  liveness  \
# 673   0.695    9    -4.969     1         0.108           0.00301      0.14
#
#      valence    tempo  duration_ms  time_signature  Like key_object
# 673    0.641  144.684       241987               4     1          A

# %% [markdown]
# ## ACOUSTICNESS.
#
# A confidence measure from 0.0 to 1.0 of whether the track is acoustic.
# - 1.0 represents high confidence the track is acoustic.

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.distplot(data[data['Like']==1]['acousticness'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['acousticness'], color='blue', bins=40)
plt.legend((1,0))

#there are a lot of disliked songs with 0 acousticness

# %% [markdown]
# ## VALENCE.
#
# This is one of the most interesting metrics that Spotify produces: A measure describing the musical positiveness conveyed by a track.
# - Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric)
# - tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.distplot(data[data['Like']==1]['valence'], color='red', bins=40)
sns.distplot(data[data['Like']==0]['valence'], color='blue', bins=40)
plt.legend((1,0))

#I was ecpecting this.... thanks LDR again

# %% [markdown]
# #### Let's check what's driving this result

# %%
sad = data[data['Like']==1].sort_values(by="valence").head(50)

# %%
sad['main_artist'].value_counts().head(10) #I was ecpecting this.... thanks LDR again
# Out:
# Lana Del Rey        5
# James Blake         5
# Ben Howard          5
# Bon Iver            3
# alt-J               2
# B Fachada           2
# Tony Anderson       1
# Volcano Choir       1
# Daniel Caesar       1
# Alice Phoebe Lou    1
# Name: main_artist, dtype: int64

# %% [markdown]
# ### Valence vs Danceability

# %%
sns.lmplot(x="valence", y="danceability", data=data, hue='Like').fig.set_size_inches(10,8)

#hard to check a cluster from disliked to liked songs 
#but we an see relationship between valence and danceability: the happier the song the better to dance

# %%
data
# Out:
#                           id                             title  \
# 0     0TLAptKgYxe7F0KewWH6X6              I Need A Forest Fire
# 1     2y0rHDTckWQ7of6tI1yc82                        Naked Life
# 2     5nVE45ithgyVocZp5XLAk6                 The Bug Collector
# 3     66VuLX5s1nrZzzQqJqPbri                        Simply Are
# 4     0X61Ud5Uzv44RvY3s1SsuO                            Imogen
# ...                      ...                               ...
# 2640  3485UyMhs2ZF50l9sIZEys                            FINAIS
# 2641  7szuecWAPwGoV1e5vGu8tl                      In Your Eyes
# 2642  4Ty4XfOHdUFIXmVtBIFMIG                             XPIDI
# 2643  1xQ6trAsedVPCdbtDAmk0c  Savage Love (Laxed - Siren Beat)
# 2644  1fobXPCu47gikLMIoyQBLy                         Tranquilo
#
#             main_artist  danceability  energy  key  loudness  mode  \
# 0              Bon Iver         0.293   0.290    2   -11.596     1
# 1            Oko Ebombo         0.624   0.321    0    -9.776     1
# 2     Haley Heynderickx         0.538   0.419   10    -9.705     1
# 3          Arto Lindsay         0.682   0.694    7   -11.393     0
# 4           Nick Mulvey         0.493   0.584    5    -6.894     1
# ...                 ...           ...     ...  ...       ...   ...
# 2640        benji price         0.750   0.615   11    -7.532     0
# 2641         The Weeknd         0.667   0.719    7    -5.371     0
# 2642        benji price         0.840   0.475    5    -6.665     0
# 2643       Jason Derulo         0.767   0.481    0    -8.520     0
# 2644             Aragão         0.770   0.546   10    -8.113     0
#
#       acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.69600          0.875000    0.1000   0.0373  128.276       257220
# 1          0.46300          0.056000    0.1030   0.3040   73.996       255030
# 2          0.77700          0.329000    0.0967   0.5290   99.622       228460
# 3          0.28900          0.714000    0.0961   0.9540  173.851       224107
# 4          0.85000          0.000353    0.1140   0.2340   86.909       255533
# ...            ...               ...       ...      ...      ...          ...
# 2640       0.64200          0.000000    0.2380   0.8330   75.986       207749
# 2641       0.00285          0.000081    0.0736   0.7170  100.021       237520
# 2642       0.64100          0.000000    0.0983   0.8820   77.006       172064
# 2643       0.23400          0.000000    0.2690   0.7610  150.076       171375
# 2644       0.62900          0.006100    0.0938   0.3820   98.032       263131
#
#       time_signature  Like key_object
# 0                  4     1          D
# 1                  4     1          C
# 2                  4     1         A♯
# 3                  4     1          G
# 4                  4     1          F
# ...              ...   ...        ...
# 2640               4     0          B
# 2641               4     0          G
# 2642               4     0          F
# 2643               4     0          C
# 2644               4     0         A♯
#
# [2645 rows x 17 columns]

# %%
### MISSING #####

#loudness
#mode
#instrumentalness
#liveness
#tempo

# %% [markdown]
# #### One Song: 3 different versions

# %%
data[data['title'] == 'Moon River']
# Out:
#                           id       title    main_artist  danceability  energy  \
# 475   41cpvQ2GyGb2BRdIRSsTqK  Moon River    Frank Ocean         0.240  0.1160
# 630   1IRRqn75jaZHp7zMT1NGbZ  Moon River  Jacob Collier         0.144  0.1540
# 1292  2KNMqqNd3sLfeN4ukKduRT  Moon River  Frank Sinatra         0.171  0.0632
#
#       key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 475     0   -13.216     1         0.877          0.000920     0.100   0.0937
# 630    10   -12.596     1         0.970          0.028400     0.103   0.0400
# 1292    0   -20.776     1         0.945          0.000027     0.121   0.1680
#
#        tempo  duration_ms  time_signature  Like key_object
# 475   77.349       188324               3     1          C
# 630   85.391       496880               4     1         A♯
# 1292  81.406       199133               3     1          C

# %% [markdown]
# While Frank (Sinatra)'s version holds the lower energy level is also the one with highest danceability, liveness and valence
