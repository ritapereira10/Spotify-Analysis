# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import json
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression

import statsmodels.api as sm
from scipy import stats
from scipy.stats import ttest_1samp, ttest_rel, ttest_ind

# %% [markdown]
# ### Connecting to Spotify

# %%
username = 'britopereiraa'
client_id ='17a3ed14ab434b33b28f19f8bea3337d'
client_secret = '7f848f9d2a024b15be5fa776b4dc7a05'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'

token = util.prompt_for_user_token(username=username, 
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

# %%
print(token)
# Out:
# BQDjzloNkoQuuLcB2DInXoilQoXgDPyHS11GyxFI0tBCtTzG-6s-zJntyXDbt-FkwCUZVyg0YWrQHYx0cf29ZXJOcq9kCw7NjfUdXIpbrA0_dEFrtGquTWsYkJimCpWgORls2Do3UVHIoeqTp52b8g-fyxI

# %%
credentials = json.load(open('authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

# %% [markdown]
# #### Test Random Forest
#
# In order to test my best classifier (Random Forest):

# %%
#using the best algorithm (have to train again...)

data = pd.read_csv('my_data.csv')

features = ['danceability', 'energy', 'key','loudness', 'mode', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms', 'time_signature']

X = data[features]
y = data['Like']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.1)

clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8641509433962264

# %% [markdown]
# #### Vodafone FM
#
# https://open.spotify.com/playlist/5QZyi299jBblzaTFW1nP4h?si=PawXR_5mSL-ZfezTCUX2Hg

# %%
#I'm going to test with a playlist from Vodafone FM 

playlist_index = 0

playlists = json.load(open('playlists_test.json'))
playlist_uri = playlists[playlist_index]['uri']
test = playlists[playlist_index]['like']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlist_uri

#just to confirm: spotify:playlist:3M2gjOU19KrxZOCYtVYUCY
# Out:
# 'spotify:user:Test_1:playlist:3M2gjOU19KrxZOCYtVYUCY'

# %%
def master_function(uri):
    uri = playlist_uri    
    username = uri.split(':')[2]
    playlist_id = uri.split(':')[4]
    results = {'items':[]}

    for n in range(0,3000,100):
        new = sp.user_playlist_tracks(username, playlist_id,  offset = n)
        results['items'] += new['items']

        playlist_tracks_data = results
        playlist_tracks_id = []
        playlist_tracks_titles = []
        playlist_tracks_artists = []

        for track in playlist_tracks_data['items']:
            playlist_tracks_id.append(track['track']['id'])
            playlist_tracks_titles.append(track['track']['name'])

        #adds a list of all artists involved in the song to the list of artists for the playlist
            for artist in track['track']['artists']:
                artist_list = []
                artist_list.append(artist['name'])
            playlist_tracks_artists.append(artist_list[0])
    
    df = pd.DataFrame([])
    for i in range(0, len(playlist_tracks_id)):
        features = sp.audio_features(playlist_tracks_id[i])
        features_df = pd.DataFrame(features)
        df = df.append(features_df)

    df['title'] = playlist_tracks_titles
    #features_df['first_artist'] = playlist_tracks_first_artists
    df['main_artist'] = playlist_tracks_artists
    #features_df = features_df.set_index('id')
    df = df[['id', 'title', 'main_artist',
                               'danceability', 'energy', 'key', 'loudness',
                               'mode', 'acousticness', 'instrumentalness',
                               'liveness', 'valence', 'tempo',
                               'duration_ms', 'time_signature']]

    return df

# %%
test_df = master_function(playlist_uri)

# %%
test_df.shape
# Out:
# (292, 15)

# %%
#passing with the test playlist 

pred = clf.predict_proba(test_df[features])[:,1]

test_df['prediction'] = pred
test_df.head()
# Out:
#                        id                title        main_artist  \
# 0  0HV1cGoX5ASBlPA1pqH8fG  Every Other Freckle              alt-J
# 0  07LpPO7qBMtJGZ3fz5Khxw              Hi-Five        Angel Olsen
# 0  6hlJIYn5IBNqcSGTS6X5Xq             My Girls  Animal Collective
# 0  6bZaumwiWjUSLSLqUyxetj          The Suburbs        Arcade Fire
# 0  4VAkPXhI7xQ6FHlUuY3RzB              Wake Up        Arcade Fire
#
#    danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0         0.528   0.707    2    -7.626     1        0.6250           0.03550
# 0         0.514   0.574    9    -7.224     1        0.0443           0.00826
# 0         0.508   0.953    4    -6.031     0        0.2560           0.04450
# 0         0.618   0.676    6    -6.127     0        0.0577           0.01970
# 0         0.254   0.787    0    -4.813     1        0.1110           0.04490
#
#    liveness  valence    tempo  duration_ms  time_signature  prediction
# 0     0.116    0.502  143.802       216004               4        0.94
# 0     0.142    0.369  125.389       177520               4        0.64
# 0     0.929    0.555  119.973       340787               4        0.46
# 0     0.343    0.537  117.783       315200               4        0.66
# 0     0.105    0.301  139.389       335333               4        0.46

# %%
print("How similar is it to my taste?", round(test_df['prediction'].mean()*100,3), "%")
# Out:
# How similar is it to my taste? 46.308 %

# %%
liked_test_songs = test_df[test_df['prediction'] >0.9]
liked_test_songs
# Out:
#                        id                                              title  \
# 0  0HV1cGoX5ASBlPA1pqH8fG                                Every Other Freckle
# 0  70WyPf8WtXvG3CgeTZZWz6                                             Nantes
# 0  3Ay3OuDTieyXTNibBO0mBy                                        Red Diamond
# 0  0kHoisnf1ddnV6MrFLWka9                                           Hang Out
# 0  7fXyuQqEBwpKtCa8PomO7B                                        Skinny Love
# 0  4ccIlWJ2R0FAI8bDyFdMTu                                           Our Love
# 0  0iHwnccPp214om2eGT5gzm                                               1998
# 0  1MJ5f5EYBC92ADD6xcz7nb                              Chamber Of Reflection
# 0  1QNUdBrQyfboTVqaf4R3hL  A pele que há em mim (Quando o dia entardeceu)...
# 0  49mNpggwlrIeNQ3Ka4JlFy                                      Pra quem quer
# 0  49mNpggwlrIeNQ3Ka4JlFy                                      Pra quem quer
# 0  0tyjkg9cN32WFK03XuPR1b                                             Falcon
# 0  5nylwlroLOv8VrDPpWIK4v        I Was Trying to Sleep When Everyone Woke Up
# 0  3ziUHk0mbwUUO0rlkT1mxA                                        O Meu Livro
# 0  5oUV6yWdDM0R9Q2CizRhIt                                          New Slang
# 0  6rxEjkoar48SssZePbtb2x                                        Crystalised
# 0  24bi3PjdcrK3t9DxFLqPXe                                        Be My World
# 0  74Y4S031TBjW4LrMCB13BL                                        Without You
# 0  0prVUHQu2xr6pI5iEbKtxo                                Beautiful Strangers
# 0  2xip1Qf69hVE9IXpoKuK94                               Little Bubble - edit
# 0  7Asow87xLxIV8v8RgIgq1h                           É preciso que eu diminua
# 0  2pKmB8t9HNJfW4bVFmnu1v                                   My Willing Heart
# 0        0.7620          0.068900    0.1050   0.8910  100.042       375903
# 0        0.7840          0.002810    0.1100   0.3010   71.821       208215
# 0        0.7500          0.004720    0.2380   0.4850   89.986       250680
# 0        0.7630          0.002420    0.0838   0.3020  109.982       242651
# 0        0.9710          0.917000    0.1160   0.2000  114.020       151137
# 0        0.4850          0.028900    0.1020   0.3220  139.874       273864
# 0        0.2160          0.088100    0.1240   0.6870  137.970       264662
# 0        0.8300          0.026500    0.0937   0.3260  133.113       213000
#
#    time_signature  prediction
# 0               4        0.94
# 0               4        0.98
# 0               4        1.00
# 0               4        0.97
# 0               4        0.95
# 0               4        0.92
# 0               4        0.93
# 0               4        0.91
# 0               3        0.97
# 0               4        0.97
# 0               4        0.97
# 0               4        0.97
# 0               4        0.98
# 0               4        0.96
# 0               4        0.97
# 0               4        1.00
# 0               4        0.93
# 0               4        0.93
# 0               4        0.99
# 0               4        0.92
# 0               4        0.95
# 0               4        0.99
# 0               4        1.00
# 0               4        0.99
# 0               4        0.92
# 0               4        0.99

# %% [markdown]
# ### Test Felipe's taste
#
# https://open.spotify.com/playlist/12Wbv8sIx84T5uh6iOoJ7V?si=aevZa-w7TqS-MFGoDmn0eQ

# %%
#I'm going to test with a playlist from Felipe: 'Uma'

playlist_index = 1

playlists = json.load(open('playlists_test.json'))
playlist_uri = playlists[playlist_index]['uri']
test = playlists[playlist_index]['like']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlist_uri
#spotify:playlist:12Wbv8sIx84T5uh6iOoJ7V
# Out:
# 'spotify:user:Test_2:playlist:12Wbv8sIx84T5uh6iOoJ7V'

# %%
felipe_df = master_function(playlist_uri)
felipe_df
# Out:
#                         id                  title          main_artist  \
# 0   0A0eOcimSNRs2EQQlH7FFJ              Três Dias       Marcelo Camelo
# 0   0MtVmhAx6CxNuxFIUc6Mj9           Elephant Gun               Beirut
# 0   6aUAF8JOd8zEl41B6I18xL            Fake Empire         The National
# 0   2vGvPQNnyybJmiqpr1HiKX        Sorriso ao Sono          Phill Veras
# 0   1PuLHwFZoh5qYK89I5YBdZ            I Will Wait       Mumford & Sons
# ..                     ...                    ...                  ...
# 0   6x14wL9HvABR2Rix8N88EH           Dylan Thomas         Conor Oberst
# 0   6xMFDLtFIiObaAuB42qHGW       Hidden Edelweiss         Spark Alaska
# 0   669PEr8I3wOswY8BANBpdh                Shaayad           Taba Chake
# 0   65wICNTM2s1PwXSgKt8f0a  Kill All Your Friends  My Chemical Romance
# 0   0tutU5E5kMR3bY8sZllpoJ      Northern Downpour  Panic! At The Disco
#
#     danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0          0.291   0.319    7   -10.465     1      0.791000          0.468000
# 0          0.171   0.626    8    -8.677     1      0.873000          0.025200
# 0          0.324   0.776    0    -6.784     1      0.151000          0.917000
# 0          0.627   0.342    2   -12.833     1      0.700000          0.166000
# 0          0.486   0.769    1    -5.140     1      0.011900          0.008320
# ..           ...     ...  ...       ...   ...           ...               ...
# 0          0.592   0.805    2    -7.995     1      0.000128          0.000211
# 0          0.758   0.347    9   -13.068     1      0.860000          0.005930
# 0          0.606   0.472    8    -8.525     1      0.685000          0.000011
# 0          0.472   0.902    7    -3.660     1      0.000825          0.000033
# 0          0.470   0.474    5    -9.406     1      0.064300          0.000000
#
#     liveness  valence    tempo  duration_ms  time_signature
# 0     0.0692    0.038  103.793       323280               3
# 0     0.0681    0.457  180.098       348893               3
# 0     0.0728    0.317  101.964       205040               3
# 0     0.0820    0.513   80.030       248480               4
# 0     0.1970    0.393  131.286       276720               4
# ..       ...      ...      ...          ...             ...
# 0     0.0916    0.505  116.072       216787               4
# 0     0.3020    0.272  143.443       220943               4
# 0     0.1140    0.439   94.972       208000               4
# 0     0.1210    0.493  102.564       268883               4
# 0     0.0645    0.241  170.173       247773               4
#
# [162 rows x 15 columns]

# %%
felipe_df.shape
# Out:
# (162, 15)

# %%
#passing with the Felipe's playlist 
pred = clf.predict_proba(felipe_df[features])[:,1]

felipe_df['prediction'] = pred
felipe_df.head()
# Out:
#                        id            title     main_artist  danceability  \
# 0  0A0eOcimSNRs2EQQlH7FFJ        Três Dias  Marcelo Camelo         0.291
# 0  0MtVmhAx6CxNuxFIUc6Mj9     Elephant Gun          Beirut         0.171
# 0  6aUAF8JOd8zEl41B6I18xL      Fake Empire    The National         0.324
# 0  2vGvPQNnyybJmiqpr1HiKX  Sorriso ao Sono     Phill Veras         0.627
# 0  1PuLHwFZoh5qYK89I5YBdZ      I Will Wait  Mumford & Sons         0.486
#
#    energy  key  loudness  mode  acousticness  instrumentalness  liveness  \
# 0   0.319    7   -10.465     1        0.7910           0.46800    0.0692
# 0   0.626    8    -8.677     1        0.8730           0.02520    0.0681
# 0   0.776    0    -6.784     1        0.1510           0.91700    0.0728
# 0   0.342    2   -12.833     1        0.7000           0.16600    0.0820
# 0   0.769    1    -5.140     1        0.0119           0.00832    0.1970
#
#    valence    tempo  duration_ms  time_signature  prediction
# 0    0.038  103.793       323280               3        0.95
# 0    0.457  180.098       348893               3        0.77
# 0    0.317  101.964       205040               3        0.63
# 0    0.513   80.030       248480               4        0.94
# 0    0.393  131.286       276720               4        0.42

# %%
print("How similar is it to my taste?", round(felipe_df['prediction'].mean()*100,3), "%")
# Out:
# How similar is it to my taste? 83.932 %

# %%
felipe_df[felipe_df['prediction'] >0.98]
# Out:
#                        id                       title  \
# 0  4f1n0muKxA870NYsPmraLN      Don't Watch Me Dancing
# 0  0ytcZAli1HSG5qHNp76y6Y                    Evaporar
# 0  78dUBuP4dmw7krQz2yEI97                Unattainable
# 0  0VqU5fPMcFo3iH1aWlDevK                   Beautiful
# 0  5AGC0c1Hqv2iiUpvvxVexq            Kathrin With a K
# 0  4Qq8rERaPWkDuZsvSWR9LL                       Volta
# 0  0QUiguzo0mWdlBk6Nvujic            You Already Know
# 0  6HTVZeVQ9J6Uiq6tHESxU9           Welcome Home, Son
# 0  1tGfetmGzNQeJ7AZUhCaar                       Grace
# 0  4CwpP3vWh0f5VsEmvdOWib                     Runaway
# 0  04NQ1q92DRbxWq6lhpVVDQ                 Be Here Now
# 0         0.746          0.872000    0.1270   0.2790   74.910       102107
# 0         0.662          0.452000    0.1110   0.1420  156.957       274553
# 0         0.882          0.000967    0.0748   0.0794   52.001       187267
# 0         0.951          0.000145    0.1050   0.3590  109.353       176600
# 0         0.804          0.002520    0.0910   0.2220  139.728       265929
# 0         0.902          0.522000    0.1090   0.0913  109.071       268456
# 0         0.874          0.329000    0.1030   0.1800  102.983       210173
# 0         0.891          0.032100    0.1070   0.2290  104.005       239880
# 0         0.802          0.000030    0.0565   0.3170  104.902       271667
# 0         0.926          0.000381    0.1120   0.2730   75.185       261920
# 0         0.941          0.537000    0.1190   0.1550  147.961       336613
# 0         0.955          0.008610    0.0846   0.1170  125.163       143329
# 0         0.880          0.004800    0.1090   0.1870  134.191       321493
# 0         0.858          0.000205    0.1060   0.3100  124.942       204368
# 0         0.917          0.296000    0.1140   0.2860  131.993       227273
# 0         0.826          0.070000    0.1530   0.3360  115.047       337308
# 0         0.885          0.000036    0.1120   0.1250  135.866       232500
# 0         0.955          0.048800    0.2600   0.4700  122.568       178375
# 0         0.479          0.052000    0.0873   0.2940  119.824       196787
# 0         0.769          0.019700    0.0769   0.2110   79.705       275627
# 0         0.804          0.000217    0.0960   0.1330  107.977       349400
# 0         0.926          0.099700    0.3710   0.2090  142.885       159231
# 0         0.920          0.167000    0.0977   0.0678   92.679       225018
# 0         0.886          0.014700    0.1170   0.1430  103.266       313935
#
#    time_signature  prediction
# 0               3        0.99
# 0               3        1.00
# 0               4        0.99
# 0               4        0.99
# 0               4        1.00
# 0               3        1.00
# 0               4        0.99
# 0               3        0.99
# 0               4        0.99
# 0               3        0.99
# 0               4        0.99
# 0               4        0.99
# 0               4        0.99
# 0               4        1.00
# 0               4        0.99
# 0               4        1.00
# 0               4        1.00
# 0               4        0.99
# 0               5        1.00
# 0               4        1.00
# 0               4        1.00
# 0               4        1.00
# 0               4        0.99
# 0               4        0.99
# 0               4        1.00
# 0               4        1.00
# 0               4        1.00
# 0               4        0.99
# 0               3        0.99
# 0               1        1.00
# 0               4        1.00
# 0               4        1.00
# 0               4        1.00
# 0               4        0.99
# 0               4        0.99
# 0               4        0.99
# 0               4        0.99
# 0               4        1.00
# 0               4        1.00
# 0               4        0.99
# 0               3        0.99
# 0               4        0.99
# 0               4        0.99
# 0               4        0.99

# %% [markdown]
# ### Clara: on repeat
#
# https://open.spotify.com/playlist/37i9dQZF1EpzPxJ69EcfPu?si=PR0kpS7VTrysJNGElmwH5g

# %%
#I'm going to test with Clara P's on repeat

playlist_index = 2

playlists = json.load(open('playlists_test.json'))
playlist_uri = playlists[playlist_index]['uri']
test = playlists[playlist_index]['like']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlist_uri
#spotify:playlist:37i9dQZF1EpzPxJ69EcfPu
# Out:
# 'spotify:user:Test_2:playlist:37i9dQZF1EpzPxJ69EcfPu'

# %%
clara_df = master_function(playlist_uri)
clara_df.shape
# Out:
# (30, 15)

# %%
pred = clf.predict_proba(clara_df[features])[:,1]

clara_df['prediction'] = pred
clara_df.head()
# Out:
#                        id                      title main_artist  \
# 0  3dUgqHR8CIRG7Ts1cyqYD0  The Wolves (Act I and II)    Bon Iver
# 0  0KpA8R3NM3N0JB4NAGbAxO              Life On Mars?   Seu Jorge
# 0  1bSpwPhAxZwlR2enJJsv7U               No Surprises   Radiohead
# 0  6Kkt27YmFyIFrcX3QXFi2o                  Liability       Lorde
# 0  71m4tRFTR2f7mQTNOmQe65                      Wash.    Bon Iver
#
#    danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0         0.465   0.164    5   -16.018     1        0.7880          0.000031
# 0         0.655   0.146   10   -16.690     1        0.8990          0.001100
# 0         0.255   0.393    5   -10.654     1        0.0577          0.003610
# 0         0.587   0.229   10   -11.254     0        0.9200          0.000000
# 0         0.317   0.149    0   -19.265     1        0.9900          0.339000
#
#    liveness  valence    tempo  duration_ms  time_signature  prediction
# 0    0.0816    0.123  117.235       322053               3        1.00
# 0    0.1190    0.279  124.104       209067               4        1.00
# 0    0.1130    0.118   76.426       229120               4        0.68
# 0    0.1000    0.379   75.670       171728               4        0.72
# 0    0.0776    0.324  163.018       298587               3        0.93

# %%
print("How similar is it to my taste?", round(clara_df['prediction'].mean()*100,3), "%")
# Out:
# How similar is it to my taste? 91.267 %

# %% [markdown]
# ### Soundtrack for Everyday Stuff
#
# https://open.spotify.com/playlist/2Krvp2ENVs0eAPM6ypduW7?si=jxTn8fJcSQS7-d2SFCcHow

# %%
playlist_index = 3

playlists = json.load(open('playlists_test.json'))
playlist_uri = playlists[playlist_index]['uri']
test = playlists[playlist_index]['like']

client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
jo_df = master_function(playlist_uri)
jo_df.shape
# Out:
# (81, 15)

# %%
pred = clf.predict_proba(jo_df[features])[:,1]

jo_df['prediction'] = pred
jo_df.head()
# Out:
#                        id                                    title  \
# 0  47Bg6IrMed1GPbxRgwH2aC                              Best Friend
# 0  5EYi2rH4LYs6M21ZLOyQTx                           Loving Is Easy
# 0  4MoDxgAbITVgPz0vYM8LXY                                    Ocean
# 0  479LUXp1pWPOaKXjbVBtzn                    Your Dead Grandfather
# 0  3DLbFY6UkPBAYTpV6IcAxl  Mandy from Mohawk (Wherever You May Be)
#
#          main_artist  danceability  energy  key  loudness  mode  acousticness  \
# 0  Rex Orange County         0.575   0.714    6    -5.247     1        0.3950
# 0        Benny Sings         0.756   0.609    3    -7.927     1        0.2170
# 0         Fruit Bats         0.641   0.275    0   -13.191     1        0.8510
# 0         Fruit Bats         0.668   0.681    0    -9.447     1        0.0867
# 0         Fruit Bats         0.671   0.676    7    -8.940     1        0.0809
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00000     0.115    0.320  144.982       262231               4
# 0           0.00474     0.096    0.537  117.023       155720               4
# 0           0.14800     0.112    0.294   82.769       198307               4
# 0           0.20600     0.101    0.571  100.006       170093               4
# 0           0.00700     0.152    0.673  120.029       227427               4
#
#    prediction
# 0        0.39
# 0        0.62
# 0        1.00
# 0        0.82
# 0        0.64

# %%
print("How similar is it to my taste?", round(jo_df['prediction'].mean()*100,3), "%")
# Out:
# How similar is it to my taste? 85.593 %
